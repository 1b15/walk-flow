# %%
import pandas as pd
import requests

# %%
def get_json(from_year, to_year):
    if not 2000 < int(from_year) < 2050 or not 2000 < int(from_year) < 2050:
        return []
    all_holidays = []
    for i in range(from_year, to_year+1):
        r = requests.get(f'https://date.nager.at/api/v2/publicholidays/{i}/CH')
        all_holidays.extend(r.json())
    return all_holidays

# %%
def set_date_index(df, col='date'):
    return df.set_index(pd.to_datetime(df[col])).drop(col, axis=1)

# %%
def filter_canton(df, can='BS'):
    return df[[(str('CH-' + can) in row) if row is not None else True for row in df.counties]]

# %%
canton = 'BS'
from_year = 2014
to_year = 2020

# %%
data = get_json(from_year, to_year)

# %%
holidays = (pd.DataFrame.from_records(data)
            .pipe(set_date_index)
            .pipe(filter_canton, can=canton))

# %%
holidays.to_csv(f'../raw_data/holidays_{canton}_{from_year}_{to_year}.csv', index=False)

# %%
holidays
# Out:
#                  localName                name countryCode  fixed  global  \
# date
# 2014-01-01         Neujahr      New Year's Day          CH   True    True
# 2014-04-18      Karfreitag         Good Friday          CH  False   False
# 2014-04-21     Ostermontag       Easter Monday          CH  False   False
# 2014-05-01  Tag der Arbeit          Labour Day          CH   True   False
# 2014-05-29        Auffahrt       Ascension Day          CH  False    True
# 2014-06-09   Pfingstmontag         Whit Monday          CH  False   False
# 2014-08-01     Bundesfeier  Swiss National Day          CH   True    True
# 2014-12-25     Weihnachten       Christmas Day          CH   True    True
# 2015-01-01         Neujahr      New Year's Day          CH   True    True
# 2015-04-03      Karfreitag         Good Friday          CH  False   False
# 2015-04-06     Ostermontag       Easter Monday          CH  False   False
# 2015-05-01  Tag der Arbeit          Labour Day          CH   True   False
# 2015-05-14        Auffahrt       Ascension Day          CH  False    True
# 2015-05-25   Pfingstmontag         Whit Monday          CH  False   False
# 2015-08-01     Bundesfeier  Swiss National Day          CH   True    True
# 2015-12-25     Weihnachten       Christmas Day          CH   True    True
# 2016-01-01         Neujahr      New Year's Day          CH   True    True
# 2016-03-25      Karfreitag         Good Friday          CH  False   False
# 2016-03-28     Ostermontag       Easter Monday          CH  False   False
# 2016-05-01  Tag der Arbeit          Labour Day          CH   True   False
# 2016-05-05        Auffahrt       Ascension Day          CH  False    True
# 2016-05-16   Pfingstmontag         Whit Monday          CH  False   False
# 2016-08-01     Bundesfeier  Swiss National Day          CH   True    True
# 2016-12-25     Weihnachten       Christmas Day          CH   True    True
# 2016-12-26     Stephanstag   St. Stephen's Day          CH   True   False
# 2017-01-01         Neujahr      New Year's Day          CH   True    True
# 2017-04-14      Karfreitag         Good Friday          CH  False   False
# 2017-04-17     Ostermontag       Easter Monday          CH  False   False
# 2017-05-01  Tag der Arbeit          Labour Day          CH   True   False
# 2017-05-25        Auffahrt       Ascension Day          CH  False    True
# 2017-06-05   Pfingstmontag         Whit Monday          CH  False   False
# 2017-08-01     Bundesfeier  Swiss National Day          CH   True    True
# 2017-12-25     Weihnachten       Christmas Day          CH   True    True
# 2018-01-01         Neujahr      New Year's Day          CH   True    True
# 2018-03-30      Karfreitag         Good Friday          CH  False   False
# 2018-04-02     Ostermontag       Easter Monday          CH  False   False
# 2018-05-01  Tag der Arbeit          Labour Day          CH   True   False
# 2018-05-10        Auffahrt       Ascension Day          CH  False    True
# 2018-05-21   Pfingstmontag         Whit Monday          CH  False   False
# 2018-08-01     Bundesfeier  Swiss National Day          CH   True    True
# 2018-12-25     Weihnachten       Christmas Day          CH   True    True
# 2019-01-01         Neujahr      New Year's Day          CH   True    True
# 2019-04-19      Karfreitag         Good Friday          CH  False   False
# 2019-04-22     Ostermontag       Easter Monday          CH  False   False
# 2019-05-01  Tag der Arbeit          Labour Day          CH   True   False
# 2019-05-30        Auffahrt       Ascension Day          CH  False    True
# 2019-06-10   Pfingstmontag         Whit Monday          CH  False   False
# 2019-08-01     Bundesfeier  Swiss National Day          CH   True    True
# 2019-12-25     Weihnachten       Christmas Day          CH   True    True
# 2020-01-01         Neujahr      New Year's Day          CH   True    True
# 2020-04-10      Karfreitag         Good Friday          CH  False   False
# 2020-04-13     Ostermontag       Easter Monday          CH  False   False
# 2020-05-01  Tag der Arbeit          Labour Day          CH   True   False
# 2020-05-21        Auffahrt       Ascension Day          CH  False    True
# 2020-06-01   Pfingstmontag         Whit Monday          CH  False   False
# 2020-08-01     Bundesfeier  Swiss National Day          CH   True    True
# 2020-12-25     Weihnachten       Christmas Day          CH   True    True
#
#                                                      counties  launchYear  \
# date
# 2014-01-01                                               None      1967.0
# 2014-04-18  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2014-04-21  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...      1642.0
# 2014-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...         NaN
# 2014-05-29                                               None         NaN
# 2014-06-09  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2014-08-01                                               None         NaN
# 2014-12-25                                               None         NaN
# 2015-01-01                                               None      1967.0
# 2015-04-03  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2015-04-06  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...      1642.0
# 2015-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...         NaN
# 2015-05-14                                               None         NaN
# 2015-05-25  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2015-08-01                                               None         NaN
# 2015-12-25                                               None         NaN
# 2016-01-01                                               None      1967.0
# 2016-03-25  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2016-03-28  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...      1642.0
# 2016-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...         NaN
# 2016-05-05                                               None         NaN
# 2016-05-16  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2016-08-01                                               None         NaN
# 2016-12-25                                               None         NaN
# 2016-12-26  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2017-01-01                                               None      1967.0
# 2017-04-14  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2017-04-17  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...      1642.0
# 2017-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...         NaN
# 2017-05-25                                               None         NaN
# 2017-06-05  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2017-08-01                                               None         NaN
# 2017-12-25                                               None         NaN
# 2018-01-01                                               None      1967.0
# 2018-03-30  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2018-04-02  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...      1642.0
# 2018-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...         NaN
# 2018-05-10                                               None         NaN
# 2018-05-21  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2018-08-01                                               None         NaN
# 2018-12-25                                               None         NaN
# 2019-01-01                                               None      1967.0
# 2019-04-19  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2019-04-22  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...      1642.0
# 2019-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...         NaN
# 2019-05-30                                               None         NaN
# 2019-06-10  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2019-08-01                                               None         NaN
# 2019-12-25                                               None         NaN
# 2020-01-01                                               None      1967.0
# 2020-04-10  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2020-04-13  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...      1642.0
# 2020-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...         NaN
# 2020-05-21                                               None         NaN
# 2020-06-01  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...         NaN
# 2020-08-01                                               None         NaN
# 2020-12-25                                               None         NaN
#
#               type
# date
# 2014-01-01  Public
# 2014-04-18  Public
# 2014-04-21  Public
# 2014-05-01  Public
# 2014-05-29  Public
# 2014-06-09  Public
# 2014-08-01  Public
# 2014-12-25  Public
# 2015-01-01  Public
# 2015-04-03  Public
# 2015-04-06  Public
# 2015-05-01  Public
# 2015-05-14  Public
# 2015-05-25  Public
# 2015-08-01  Public
# 2015-12-25  Public
# 2016-01-01  Public
# 2016-03-25  Public
# 2016-03-28  Public
# 2016-05-01  Public
# 2016-05-05  Public
# 2016-05-16  Public
# 2016-08-01  Public
# 2016-12-25  Public
# 2016-12-26  Public
# 2017-01-01  Public
# 2017-04-14  Public
# 2017-04-17  Public
# 2017-05-01  Public
# 2017-05-25  Public
# 2017-06-05  Public
# 2017-08-01  Public
# 2017-12-25  Public
# 2018-01-01  Public
# 2018-03-30  Public
# 2018-04-02  Public
# 2018-05-01  Public
# 2018-05-10  Public
# 2018-05-21  Public
# 2018-08-01  Public
# 2018-12-25  Public
# 2019-01-01  Public
# 2019-04-19  Public
# 2019-04-22  Public
# 2019-05-01  Public
# 2019-05-30  Public
# 2019-06-10  Public
# 2019-08-01  Public
# 2019-12-25  Public
# 2020-01-01  Public
# 2020-04-10  Public
# 2020-04-13  Public
# 2020-05-01  Public
# 2020-05-21  Public
# 2020-06-01  Public
# 2020-08-01  Public
# 2020-12-25  Public
