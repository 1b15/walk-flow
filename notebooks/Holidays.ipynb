# %%
import pandas as pd
import requests

def get_json(from_year, to_year):
    if not 2000 < int(from_year) < 2050 or not 2000 < int(from_year) < 2050:
        return []
    all_holidays = []
    for i in range(from_year, to_year+1):
        r = requests.get(f'https://date.nager.at/api/v2/publicholidays/{i}/CH')
        all_holidays.extend(r.json())
    return all_holidays

def set_date_index(df, col='date'):
    return df.set_index(pd.to_datetime(df[col])).drop(col, axis=1)

def filter_canton(df, can='BS'):
    return df[[(str('CH-' + can) in row) if row is not None else True for row in df.counties]]

canton = 'BS'
from_year = 2014
to_year = 2020

data = get_json(from_year, to_year)

# %%
holidays = (pd.DataFrame.from_records(data)
            .pipe(set_date_index)
            .pipe(filter_canton, can=canton))

# %%
holidays.to_csv(f'../raw_data/holidays_{canton}_{from_year}_{to_year}.csv', columns=['name'])

# %%
holidays
# Out:
#                                                      counties countryCode  \
# date
# 2014-01-01                                               None          CH
# 2014-04-18  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2014-04-21  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2014-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...          CH
# 2014-05-29                                               None          CH
# 2014-06-09  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2014-08-01                                               None          CH
# 2014-12-25                                               None          CH
# 2015-01-01                                               None          CH
# 2015-04-03  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2015-04-06  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2015-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...          CH
# 2015-05-14                                               None          CH
# 2015-05-25  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2015-08-01                                               None          CH
# 2015-12-25                                               None          CH
# 2016-01-01                                               None          CH
# 2016-03-25  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2016-03-28  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2016-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...          CH
# 2016-05-05                                               None          CH
# 2016-05-16  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2016-08-01                                               None          CH
# 2016-12-25                                               None          CH
# 2016-12-26  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2017-01-01                                               None          CH
# 2017-04-14  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2017-04-17  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2017-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...          CH
# 2017-05-25                                               None          CH
# 2017-06-05  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2017-08-01                                               None          CH
# 2017-12-25                                               None          CH
# 2018-01-01                                               None          CH
# 2018-03-30  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2018-04-02  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2018-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...          CH
# 2018-05-10                                               None          CH
# 2018-05-21  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2018-08-01                                               None          CH
# 2018-12-25                                               None          CH
# 2019-01-01                                               None          CH
# 2019-04-19  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2019-04-22  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2019-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...          CH
# 2019-05-30                                               None          CH
# 2019-06-10  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2019-08-01                                               None          CH
# 2019-12-25                                               None          CH
# 2020-01-01                                               None          CH
# 2020-04-10  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2020-04-13  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2020-05-01  [CH-ZH, CH-FR, CH-SO, CH-BS, CH-BL, CH-SH, CH-...          CH
# 2020-05-21                                               None          CH
# 2020-06-01  [CH-ZH, CH-BE, CH-LU, CH-UR, CH-SZ, CH-OW, CH-...          CH
# 2020-08-01                                               None          CH
# 2020-12-25                                               None          CH
#
#             fixed  global  launchYear       localName                name  \
# date
# 2014-01-01   True    True      1967.0         Neujahr      New Year's Day
# 2014-04-18  False   False         NaN      Karfreitag         Good Friday
# 2014-04-21  False   False      1642.0     Ostermontag       Easter Monday
# 2014-05-01   True   False         NaN  Tag der Arbeit          Labour Day
# 2014-05-29  False    True         NaN        Auffahrt       Ascension Day
# 2014-06-09  False   False         NaN   Pfingstmontag         Whit Monday
# 2014-08-01   True    True         NaN     Bundesfeier  Swiss National Day
# 2014-12-25   True    True         NaN     Weihnachten       Christmas Day
# 2015-01-01   True    True      1967.0         Neujahr      New Year's Day
# 2015-04-03  False   False         NaN      Karfreitag         Good Friday
# 2015-04-06  False   False      1642.0     Ostermontag       Easter Monday
# 2015-05-01   True   False         NaN  Tag der Arbeit          Labour Day
# 2015-05-14  False    True         NaN        Auffahrt       Ascension Day
# 2015-05-25  False   False         NaN   Pfingstmontag         Whit Monday
# 2015-08-01   True    True         NaN     Bundesfeier  Swiss National Day
# 2015-12-25   True    True         NaN     Weihnachten       Christmas Day
# 2016-01-01   True    True      1967.0         Neujahr      New Year's Day
# 2016-03-25  False   False         NaN      Karfreitag         Good Friday
# 2016-03-28  False   False      1642.0     Ostermontag       Easter Monday
# 2016-05-01   True   False         NaN  Tag der Arbeit          Labour Day
# 2016-05-05  False    True         NaN        Auffahrt       Ascension Day
# 2016-05-16  False   False         NaN   Pfingstmontag         Whit Monday
# 2016-08-01   True    True         NaN     Bundesfeier  Swiss National Day
# 2016-12-25   True    True         NaN     Weihnachten       Christmas Day
# 2016-12-26   True   False         NaN     Stephanstag   St. Stephen's Day
# 2017-01-01   True    True      1967.0         Neujahr      New Year's Day
# 2017-04-14  False   False         NaN      Karfreitag         Good Friday
# 2017-04-17  False   False      1642.0     Ostermontag       Easter Monday
# 2017-05-01   True   False         NaN  Tag der Arbeit          Labour Day
# 2017-05-25  False    True         NaN        Auffahrt       Ascension Day
# 2017-06-05  False   False         NaN   Pfingstmontag         Whit Monday
# 2017-08-01   True    True         NaN     Bundesfeier  Swiss National Day
# 2017-12-25   True    True         NaN     Weihnachten       Christmas Day
# 2018-01-01   True    True      1967.0         Neujahr      New Year's Day
# 2018-03-30  False   False         NaN      Karfreitag         Good Friday
# 2018-04-02  False   False      1642.0     Ostermontag       Easter Monday
# 2018-05-01   True   False         NaN  Tag der Arbeit          Labour Day
# 2018-05-10  False    True         NaN        Auffahrt       Ascension Day
# 2018-05-21  False   False         NaN   Pfingstmontag         Whit Monday
# 2018-08-01   True    True         NaN     Bundesfeier  Swiss National Day
# 2018-12-25   True    True         NaN     Weihnachten       Christmas Day
# 2019-01-01   True    True      1967.0         Neujahr      New Year's Day
# 2019-04-19  False   False         NaN      Karfreitag         Good Friday
# 2019-04-22  False   False      1642.0     Ostermontag       Easter Monday
# 2019-05-01   True   False         NaN  Tag der Arbeit          Labour Day
# 2019-05-30  False    True         NaN        Auffahrt       Ascension Day
# 2019-06-10  False   False         NaN   Pfingstmontag         Whit Monday
# 2019-08-01   True    True         NaN     Bundesfeier  Swiss National Day
# 2019-12-25   True    True         NaN     Weihnachten       Christmas Day
# 2020-01-01   True    True      1967.0         Neujahr      New Year's Day
# 2020-04-10  False   False         NaN      Karfreitag         Good Friday
# 2020-04-13  False   False      1642.0     Ostermontag       Easter Monday
# 2020-05-01   True   False         NaN  Tag der Arbeit          Labour Day
# 2020-05-21  False    True         NaN        Auffahrt       Ascension Day
# 2020-06-01  False   False         NaN   Pfingstmontag         Whit Monday
# 2020-08-01   True    True         NaN     Bundesfeier  Swiss National Day
# 2020-12-25   True    True         NaN     Weihnachten       Christmas Day
#
#               type
# date
# 2014-01-01  Public
# 2014-04-18  Public
# 2014-04-21  Public
# 2014-05-01  Public
# 2014-05-29  Public
# 2014-06-09  Public
# 2014-08-01  Public
# 2014-12-25  Public
# 2015-01-01  Public
# 2015-04-03  Public
# 2015-04-06  Public
# 2015-05-01  Public
# 2015-05-14  Public
# 2015-05-25  Public
# 2015-08-01  Public
# 2015-12-25  Public
# 2016-01-01  Public
# 2016-03-25  Public
# 2016-03-28  Public
# 2016-05-01  Public
# 2016-05-05  Public
# 2016-05-16  Public
# 2016-08-01  Public
# 2016-12-25  Public
# 2016-12-26  Public
# 2017-01-01  Public
# 2017-04-14  Public
# 2017-04-17  Public
# 2017-05-01  Public
# 2017-05-25  Public
# 2017-06-05  Public
# 2017-08-01  Public
# 2017-12-25  Public
# 2018-01-01  Public
# 2018-03-30  Public
# 2018-04-02  Public
# 2018-05-01  Public
# 2018-05-10  Public
# 2018-05-21  Public
# 2018-08-01  Public
# 2018-12-25  Public
# 2019-01-01  Public
# 2019-04-19  Public
# 2019-04-22  Public
# 2019-05-01  Public
# 2019-05-30  Public
# 2019-06-10  Public
# 2019-08-01  Public
# 2019-12-25  Public
# 2020-01-01  Public
# 2020-04-10  Public
# 2020-04-13  Public
# 2020-05-01  Public
# 2020-05-21  Public
# 2020-06-01  Public
# 2020-08-01  Public
# 2020-12-25  Public
